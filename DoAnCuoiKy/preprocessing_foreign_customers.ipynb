# %%
import pandas as pd

# %%
df = pd.read_csv("foreign_tourist.csv")
info = df.info()
summary = df.describe(include='all')
missing_value = df.isnull().sum()
columns = df.columns
info, summary,missing_value,columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1895 entries, 0 to 1894
# Data columns (total 10 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Năm                                                1895 non-null   int64
#  1   Tháng                                              1895 non-null   object
#  2   Chỉ tiêu                                           1895 non-null   object
#  3   Ước tính mỗi tháng                                 1856 non-null   object
#  4   Tổng lượt khách cả năm                             1892 non-null   object
#  5   So với tháng trước (%)                             1852 non-null   object
#  6   So sánh tháng này ở năm trước(%)                   1424 non-null   object
#  7   So sánh tổng lượt khách với cùng kỳ năm trước (%)  1278 non-null   object
# ...

# %%
# GIỚI THIỆU DỮ LIỆU
# ROWS: 1895
# CỘT: 10 - TRONG ĐÓ CÓ 2 CỘT TRỐNG
# GIỚI THIỆU CÁC CỘT:
#     1.Năm
#     2.Tháng
#     3.Chỉ tiêu: 48 giá trị khác nhau: hiển thị tên các nước
# Thông tin tổng quát:
# Dữ liệu mất giá trị (missing values):
#     Ước tính mỗi tháng: 39 giá trị thiếu.
#     Tổng lượt khách cả năm: 3 giá trị thiếu.
#     So với tháng trước (%): 43 giá trị thiếu.
#     So sánh tháng này ở năm trước (%): 471 giá trị thiếu.
#     So sánh tổng lượt khách với cùng kỳ năm trước (%): 617 giá trị thiếu.
#     Unnamed: 8 và Unnamed: 9: 100% giá trị thiếu (1895 giá trị).
# Định dạng dữ liệu chưa được chuẩn hóa: Một số cột như "Ước tính mỗi tháng" và 
#"Tổng lượt khách cả năm" chứa dữ liệu dạng chuỗi thay vì dạng số.

# %%
# Kế hoạch tiền xử lý dữ liệu:
# Xóa các cột không cần thiết:

# Xóa cột Unnamed: 8 và Unnamed: 9 vì không có dữ liệu.
# Chuyển đổi kiểu dữ liệu:

# Chuyển đổi các cột dạng số như "Ước tính mỗi tháng", "Tổng lượt khách cả năm", "So với tháng trước (%)", "So sánh tháng này ở năm trước (%)", "So sánh tổng lượt khách với cùng kỳ năm trước (%)" về kiểu float hoặc int (loại bỏ ký tự không phải số nếu có).
# Xử lý giá trị thiếu (Missing Values):

# Điền giá trị trung bình (mean) cho các cột số.
# Loại bỏ (drop) các dòng có giá trị thiếu quá lớn (trên 50% giá trị cột).
# Kiểm tra và xử lý Outliers (Dữ liệu ngoại lệ):

# Dùng biểu đồ boxplot để phát hiện outliers.
# Thay thế outliers bằng giá trị percentiles (ví dụ 5% và 95%).
# Tạo biến Dummy (Nếu cần):

# Cột "Tháng" và "Chỉ tiêu" có thể chuyển đổi thành các biến dummy nếu cần thiết cho phân tích.
# Kiểm tra đa cộng tuyến (Multicollinearity):

# Sử dụng hệ số tương quan (correlation matrix) để kiểm tra sự tương quan giữa các biến.
# Phân tích phân phối dữ liệu:

# Biểu đồ histogram hoặc KDE plot để xem phân bố của các cột số.

# %%
df =
